# %%
# !pip install xgboost
# !pip install lightgbm
# Out:
# Requirement already satisfied: xgboost in d:\image processing softwares\lib\site-packages (2.0.2)
# Requirement already satisfied: numpy in d:\image processing softwares\lib\site-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in d:\image processing softwares\lib\site-packages (from xgboost) (1.10.0)
# Requirement already satisfied: lightgbm in d:\image processing softwares\lib\site-packages (4.1.0)
# Requirement already satisfied: numpy in d:\image processing softwares\lib\site-packages (from lightgbm) (1.23.5)
# Requirement already satisfied: scipy in d:\image processing softwares\lib\site-packages (from lightgbm) (1.10.0)

# %% [markdown]
# ## Import Libraries

# %%
#importing the libraries
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
import lightgbm as lgb

# %% [markdown]
# ## import Data Set

# %%
#load the dataset
df = pd.read_csv(r"D:\Git Hub\SI-GuidedProject-603567-1697618783\Project Development Phase\Regression\Dataset\train.csv")

# %%
#displaying the first five rows
df.head()
# Out:
#    Id        Date   Time  CO2_(dinning-room)  CO2_room  \
# 0   0  13/03/2012  11:45             216.560   221.920
# 1   1  13/03/2012  12:00             219.947   220.363
# 2   2  13/03/2012  12:15             219.403   218.933
# 3   3  13/03/2012  12:30             218.613   217.045
# 4   4  13/03/2012  12:45             217.714   216.080
#
#    Relative_humidity_(dinning-room)  Relative_humidity_room  \
# 0                           39.9125                 42.4150
# 1                           39.9267                 42.2453
# 2                           39.7720                 42.2267
# 3                           39.7760                 42.0987
# 4                           39.7757                 42.0686
#
#    Lighting_(dinning-room)  Lighting_room  Meteo_Rain  Meteo_Sun_dusk  \
# 0                  81.6650        113.520         0.0         623.360
# 1                  81.7413        113.605         0.0         623.211
# 2                  81.4240        113.600         0.0         622.656
# 3                  81.5013        113.344         0.0         622.571
# 4                  81.4657        113.034         0.0         622.400
#
#    Meteo_Wind  Meteo_Sun_light_in_west_facade  Meteo_Sun_light_in_east_facade  \
# 0     1.42625                         9690.24                        12604.20
# 1     1.59200                        11022.00                        10787.20
# 2     1.89133                        13960.50                         9669.63
# 3     1.82800                        18511.20                         9648.13
# 4     2.36071                        26349.00                         9208.32
#
#    Meteo_Sun_light_in_south_facade  Meteo_Sun_irradiance  \
# 0                          95436.8               758.880
# 1                          95436.8               762.069
# 2                          95398.6               766.251
# 3                          95360.3               766.037
# 4                          95354.9               762.743
#
#    Outdoor_relative_humidity_Sensor  Day_of_the_week  Indoor_temperature_room
# 0                           48.3750              2.0                  17.8275
# 1                           47.8080              2.0                  18.1207
# 2                           47.4320              2.0                  18.4367
# 3                           47.0240              2.0                  18.7513
# 4                           45.4743              2.0                  19.0414

# %% [markdown]
# ## Data Visualisation

# %%
#univariate analysis
plt.figure(figsize=(10,5))
sns.histplot(data=df, x='Indoor_temperature_room',)
# Out:
# <Axes: xlabel='Indoor_temperature_room', ylabel='Count'>

# %% [markdown]
# Above graph shows that the Indoor_temperature_room feature shows normal distribution

# %%
#Bivariate analysis
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x='Relative_humidity_room', y='Relative_humidity_(dinning-room)')
# Out:
# <Axes: xlabel='Relative_humidity_room', ylabel='Relative_humidity_(dinning-room)'>

# %% [markdown]
# Independent variable = Relative_humidity_room
#
# dependent variable = Relative_humidity_(dinning-room)
#
# above graph represents good linear relation between above two varables

# %%
#multivariate analysis
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x='CO2_room', y='Relative_humidity_(dinning-room)', hue='Indoor_temperature_room')
# Out:
# <Axes: xlabel='CO2_room', ylabel='Relative_humidity_(dinning-room)'>

# %% [markdown]
# According to above graph as CO2 increase in the room, indoor temperature also increases, room_temperature is low when co2 is arround 200 and humidity is between 30-43

# %%
#Descriptive Analysis
df.describe()
# Out:
#                 Id  CO2_(dinning-room)     CO2_room  \
# count  2764.000000         2764.000000  2764.000000
# mean   1381.500000          208.479123   211.065844
# std     798.042397           27.032686    28.469144
# min       0.000000          187.339000   188.907000
# 25%     690.750000          200.893250   202.682750
# 50%    1381.500000          207.045500   209.408000
# 75%    2072.250000          211.245500   213.218750
# max    2763.000000          594.389000   609.237000
#
#        Relative_humidity_(dinning-room)  Relative_humidity_room  \
# count                       2764.000000             2764.000000
# mean                          44.878420               47.321220
# std                            6.587440                7.557795
# min                           27.084000               29.594700
# 25%                           40.351975               42.531325
# 50%                           45.434650               47.534700
# 75%                           49.352675               52.685975
# max                           60.957300               62.594700
#
#        Lighting_(dinning-room)  Lighting_room   Meteo_Rain  Meteo_Sun_dusk  \
# count              2764.000000    2764.000000  2764.000000     2764.000000
# mean                 26.745381      40.732571     0.047033      325.369289
# std                  23.298441      42.326087     0.206705      305.062614
# min                  10.740000      11.328000     0.000000        0.606667
# 25%                  11.588700      13.265300     0.000000        0.650000
# 50%                  11.801300      17.690000     0.000000      611.797000
# 75%                  31.224000      52.057350     0.000000      619.210750
# max                 110.693000     162.965000     1.000000      624.960000
#
#         Meteo_Wind  Meteo_Sun_light_in_west_facade  \
# count  2764.000000                     2764.000000
# mean      1.108531                    14936.617682
# std       1.161283                    25964.049455
# min       0.000000                        0.000000
# 25%       0.094833                        0.000000
# 50%       0.659000                        0.000000
# 75%       1.971497                    15088.000000
# max       6.321330                    95278.400000
#
#        Meteo_Sun_light_in_east_facade  Meteo_Sun_light_in_south_facade  \
# count                     2764.000000                      2764.000000
# mean                     12248.000148                     22047.525813
# std                      21758.550527                     32709.387051
# min                          0.000000                         0.000000
# 25%                          0.000000                         0.000000
# 50%                          0.000000                         0.000000
# 75%                      11131.275000                     38736.575000
# max                      85535.400000                     95704.400000
#
#        Meteo_Sun_irradiance  Outdoor_relative_humidity_Sensor  \
# count           2764.000000                       2764.000000
# mean             215.010017                         55.981988
# std              297.234046                         13.019610
# min               -4.164670                         22.260700
# 25%               -3.381330                         46.430675
# 50%                3.922000                         57.477350
# 75%              435.434500                         65.649325
# max             1028.270000                         83.805300
#
#        Day_of_the_week  Indoor_temperature_room
# count      2764.000000              2764.000000
# mean          3.954438                18.824852
# std           1.991799                 2.821178
# min           1.000000                11.076000
# 25%           2.000000                17.060350
# 50%           4.000000                19.021000
# 75%           6.000000                20.828700
# max           7.000000                24.944000

# %% [markdown]
# above we get total_count as count, mean, standard deviation, quantriles bu using describe function

# %%
#correlation between columns
corr = df.corr()
corr
# Out:
# C:\Users\ajayp\AppData\Local\Temp\ipykernel_23920\2195921255.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
#                                         Id  CO2_(dinning-room)  CO2_room  \
# Id                                1.000000           -0.226771 -0.242380
# CO2_(dinning-room)               -0.226771            1.000000  0.925522
# CO2_room                         -0.242380            0.925522  1.000000
# Relative_humidity_(dinning-room)  0.207623           -0.004698 -0.013242
# Relative_humidity_room            0.177251           -0.027170 -0.022244
# Lighting_(dinning-room)          -0.064395            0.255059  0.241727
# Lighting_room                    -0.014088            0.214517  0.196714
# Meteo_Rain                       -0.075370           -0.078120 -0.077395
# Meteo_Sun_dusk                    0.013842            0.121910  0.108002
# Meteo_Wind                        0.027212            0.029190  0.009194
# Meteo_Sun_light_in_west_facade   -0.040328            0.146489  0.115046
# Meteo_Sun_light_in_east_facade   -0.012653            0.023633  0.012565
# Meteo_Sun_light_in_south_facade  -0.112416            0.256665  0.242475
# Meteo_Sun_irradiance              0.000025            0.226493  0.204212
# Outdoor_relative_humidity_Sensor -0.042246           -0.028235 -0.009462
# Day_of_the_week                  -0.036023           -0.135281 -0.129085
# Indoor_temperature_room           0.246559            0.061361  0.056195
#
#                                   Relative_humidity_(dinning-room)  \
# Id                                                        0.207623
# CO2_(dinning-room)                                       -0.004698
# CO2_room                                                 -0.013242
# Relative_humidity_(dinning-room)                          1.000000
# Relative_humidity_room                                    0.931267
# Lighting_(dinning-room)                                  -0.046600
# Lighting_room                                            -0.017654
# Meteo_Rain                                               -0.081597
# Meteo_Sun_dusk                                           -0.052456
# Meteo_Wind                                               -0.197537
# Meteo_Sun_light_in_west_facade                           -0.100505
# Meteo_Sun_light_in_east_facade                           -0.016503
# Meteo_Sun_light_in_south_facade                          -0.057019
# Meteo_Sun_irradiance                                     -0.045240
# Outdoor_relative_humidity_Sensor                          0.696973
# Day_of_the_week                                          -0.058968
# Indoor_temperature_room                                  -0.275193
#
#                                   Relative_humidity_room  \
# Id                                              0.177251
# CO2_(dinning-room)                             -0.027170
# CO2_room                                       -0.022244
# Relative_humidity_(dinning-room)                0.931267
# Relative_humidity_room                          1.000000
# Lighting_(dinning-room)                        -0.116434
# Lighting_room                                  -0.092876
# Meteo_Rain                                      0.051322
# Meteo_Sun_dusk                                 -0.083595
# Meteo_Wind                                     -0.153276
# Meteo_Sun_light_in_west_facade                 -0.130920
# Meteo_Sun_light_in_east_facade                 -0.067384
# Meteo_Sun_light_in_south_facade                -0.133493
# Meteo_Sun_irradiance                           -0.120310
# Outdoor_relative_humidity_Sensor                0.809993
# Day_of_the_week                                -0.103301
# Indoor_temperature_room                        -0.417901
#
#                                   Lighting_(dinning-room)  Lighting_room  \
# Id                                              -0.064395      -0.014088
# CO2_(dinning-room)                               0.255059       0.214517
# CO2_room                                         0.241727       0.196714
# Relative_humidity_(dinning-room)                -0.046600      -0.017654
# Relative_humidity_room                          -0.116434      -0.092876
# Lighting_(dinning-room)                          1.000000       0.948650
# Lighting_room                                    0.948650       1.000000
# Meteo_Rain                                      -0.108220      -0.112234
# Meteo_Sun_dusk                                   0.631730       0.629562
# Meteo_Wind                                       0.545034       0.475906
# Meteo_Sun_light_in_west_facade                   0.426375       0.315060
# Meteo_Sun_light_in_east_facade                   0.404444       0.565679
# Meteo_Sun_light_in_south_facade                  0.949340       0.965505
# Meteo_Sun_irradiance                             0.948145       0.932237
# Outdoor_relative_humidity_Sensor                -0.220635      -0.182360
# Day_of_the_week                                  0.045991       0.051008
# Indoor_temperature_room                          0.069264       0.002253
#
#                                   Meteo_Rain  Meteo_Sun_dusk  Meteo_Wind  \
# Id                                 -0.075370        0.013842    0.027212
# CO2_(dinning-room)                 -0.078120        0.121910    0.029190
# CO2_room                           -0.077395        0.108002    0.009194
# Relative_humidity_(dinning-room)   -0.081597       -0.052456   -0.197537
# Relative_humidity_room              0.051322       -0.083595   -0.153276
# Lighting_(dinning-room)            -0.108220        0.631730    0.545034
# Lighting_room                      -0.112234        0.629562    0.475906
# Meteo_Rain                          1.000000       -0.005661    0.239575
# Meteo_Sun_dusk                     -0.005661        1.000000    0.541814
# Meteo_Wind                          0.239575        0.541814    1.000000
# Meteo_Sun_light_in_west_facade     -0.116674        0.554923    0.619047
# Meteo_Sun_light_in_east_facade     -0.105728        0.544312    0.065801
# Meteo_Sun_light_in_south_facade    -0.137075        0.653682    0.475860
# Meteo_Sun_irradiance               -0.139149        0.711831    0.618184
# Outdoor_relative_humidity_Sensor    0.294056       -0.214353   -0.292395
# Day_of_the_week                    -0.172599        0.008430   -0.052182
# Indoor_temperature_room            -0.262621        0.068897    0.220667
#
#                                   Meteo_Sun_light_in_west_facade  \
# Id                                                     -0.040328
# CO2_(dinning-room)                                      0.146489
# CO2_room                                                0.115046
# Relative_humidity_(dinning-room)                       -0.100505
# Relative_humidity_room                                 -0.130920
# Lighting_(dinning-room)                                 0.426375
# Lighting_room                                           0.315060
# Meteo_Rain                                             -0.116674
# Meteo_Sun_dusk                                          0.554923
# Meteo_Wind                                              0.619047
# Meteo_Sun_light_in_west_facade                          1.000000
# Meteo_Sun_light_in_east_facade                          0.111847
# Meteo_Sun_light_in_south_facade                         0.416614
# Meteo_Sun_irradiance                                    0.601980
# Outdoor_relative_humidity_Sensor                       -0.359863
# Day_of_the_week                                         0.033980
# Indoor_temperature_room                                 0.335288
#
#                                   Meteo_Sun_light_in_east_facade  \
# Id                                                     -0.012653
# CO2_(dinning-room)                                      0.023633
# CO2_room                                                0.012565
# Relative_humidity_(dinning-room)                       -0.016503
# Relative_humidity_room                                 -0.067384
# Lighting_(dinning-room)                                 0.404444
# Lighting_room                                           0.565679
# Meteo_Rain                                             -0.105728
# Meteo_Sun_dusk                                          0.544312
# Meteo_Wind                                              0.065801
# Meteo_Sun_light_in_west_facade                          0.111847
# Meteo_Sun_light_in_east_facade                          1.000000
# Meteo_Sun_light_in_south_facade                         0.609949
# Meteo_Sun_irradiance                                    0.490077
# Outdoor_relative_humidity_Sensor                       -0.060787
# Day_of_the_week                                         0.082131
# Indoor_temperature_room                                -0.269034
#
#                                   Meteo_Sun_light_in_south_facade  \
# Id                                                      -0.112416
# CO2_(dinning-room)                                       0.256665
# CO2_room                                                 0.242475
# Relative_humidity_(dinning-room)                        -0.057019
# Relative_humidity_room                                  -0.133493
# Lighting_(dinning-room)                                  0.949340
# Lighting_room                                            0.965505
# Meteo_Rain                                              -0.137075
# Meteo_Sun_dusk                                           0.653682
# Meteo_Wind                                               0.475860
# Meteo_Sun_light_in_west_facade                           0.416614
# Meteo_Sun_light_in_east_facade                           0.609949
# Meteo_Sun_light_in_south_facade                          1.000000
# Meteo_Sun_irradiance                                     0.948131
# Outdoor_relative_humidity_Sensor                        -0.215892
# Day_of_the_week                                          0.067982
# Indoor_temperature_room                                  0.000072
#
#                                   Meteo_Sun_irradiance  \
# Id                                            0.000025
# CO2_(dinning-room)                            0.226493
# CO2_room                                      0.204212
# Relative_humidity_(dinning-room)             -0.045240
# Relative_humidity_room                       -0.120310
# Lighting_(dinning-room)                       0.948145
# Lighting_room                                 0.932237
# Meteo_Rain                                   -0.139149
# Meteo_Sun_dusk                                0.711831
# Meteo_Wind                                    0.618184
# Meteo_Sun_light_in_west_facade                0.601980
# Meteo_Sun_light_in_east_facade                0.490077
# Meteo_Sun_light_in_south_facade               0.948131
# Meteo_Sun_irradiance                          1.000000
# Outdoor_relative_humidity_Sensor             -0.282847
# Day_of_the_week                               0.051648
# Indoor_temperature_room                       0.123390
#
#                                   Outdoor_relative_humidity_Sensor  \
# Id                                                       -0.042246
# CO2_(dinning-room)                                       -0.028235
# CO2_room                                                 -0.009462
# Relative_humidity_(dinning-room)                          0.696973
# Relative_humidity_room                                    0.809993
# Lighting_(dinning-room)                                  -0.220635
# Lighting_room                                            -0.182360
# Meteo_Rain                                                0.294056
# Meteo_Sun_dusk                                           -0.214353
# Meteo_Wind                                               -0.292395
# Meteo_Sun_light_in_west_facade                           -0.359863
# Meteo_Sun_light_in_east_facade                           -0.060787
# Meteo_Sun_light_in_south_facade                          -0.215892
# Meteo_Sun_irradiance                                     -0.282847
# Outdoor_relative_humidity_Sensor                          1.000000
# Day_of_the_week                                          -0.228048
# Indoor_temperature_room                                  -0.549681
#
#                                   Day_of_the_week  Indoor_temperature_room
# Id                                      -0.036023                 0.246559
# CO2_(dinning-room)                      -0.135281                 0.061361
# CO2_room                                -0.129085                 0.056195
# Relative_humidity_(dinning-room)        -0.058968                -0.275193
# Relative_humidity_room                  -0.103301                -0.417901
# Lighting_(dinning-room)                  0.045991                 0.069264
# Lighting_room                            0.051008                 0.002253
# Meteo_Rain                              -0.172599                -0.262621
# Meteo_Sun_dusk                           0.008430                 0.068897
# Meteo_Wind                              -0.052182                 0.220667
# Meteo_Sun_light_in_west_facade           0.033980                 0.335288
# Meteo_Sun_light_in_east_facade           0.082131                -0.269034
# Meteo_Sun_light_in_south_facade          0.067982                 0.000072
# Meteo_Sun_irradiance                     0.051648                 0.123390
# Outdoor_relative_humidity_Sensor        -0.228048                -0.549681
# Day_of_the_week                          1.000000                 0.016517
# Indoor_temperature_room                  0.016517                 1.000000

# %%
#plot above correlation
plt.subplots(figsize=(20,15))
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# In above we can see that similar feature like lighting, humidity, CO2 for room and dinning room are highly correlative
#
# and Meteo_Sun_light_in_south_facade and Meteo_Sun_irradian are also highly correlativwe with lighting for both room and dinning room

# %% [markdown]
# ## Data Preprocessing

# %%
#information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2764 entries, 0 to 2763
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Id                                2764 non-null   int64
#  1   Date                              2764 non-null   object
#  2   Time                              2764 non-null   object
#  3   CO2_(dinning-room)                2764 non-null   float64
#  4   CO2_room                          2764 non-null   float64
#  5   Relative_humidity_(dinning-room)  2764 non-null   float64
#  6   Relative_humidity_room            2764 non-null   float64
#  7   Lighting_(dinning-room)           2764 non-null   float64
#  8   Lighting_room                     2764 non-null   float64
#  9   Meteo_Rain                        2764 non-null   float64
#  10  Meteo_Sun_dusk                    2764 non-null   float64
#  11  Meteo_Wind                        2764 non-null   float64
#  12  Meteo_Sun_light_in_west_facade    2764 non-null   float64
#  13  Meteo_Sun_light_in_east_facade    2764 non-null   float64
#  14  Meteo_Sun_light_in_south_facade   2764 non-null   float64
#  15  Meteo_Sun_irradiance              2764 non-null   float64
#  16  Outdoor_relative_humidity_Sensor  2764 non-null   float64
#  17  Day_of_the_week                   2764 non-null   float64
#  18  Indoor_temperature_room           2764 non-null   float64
# dtypes: float64(16), int64(1), object(2)
# memory usage: 410.4+ KB

# %%
#checking for null values
#get sum of null values
df.isnull().sum()
# Out:
# Id                                  0
# Date                                0
# Time                                0
# CO2_(dinning-room)                  0
# CO2_room                            0
# Relative_humidity_(dinning-room)    0
# Relative_humidity_room              0
# Lighting_(dinning-room)             0
# Lighting_room                       0
# Meteo_Rain                          0
# Meteo_Sun_dusk                      0
# Meteo_Wind                          0
# Meteo_Sun_light_in_west_facade      0
# Meteo_Sun_light_in_east_facade      0
# Meteo_Sun_light_in_south_facade     0
# Meteo_Sun_irradiance                0
# Outdoor_relative_humidity_Sensor    0
# Day_of_the_week                     0
# Indoor_temperature_room             0
# dtype: int64

# %% [markdown]
# above it is seen that no null values in our data and now there is no need to handle them

# %%
#Handling categorical Data
#again through indormation
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2764 entries, 0 to 2763
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Id                                2764 non-null   int64
#  1   Date                              2764 non-null   object
#  2   Time                              2764 non-null   object
#  3   CO2_(dinning-room)                2764 non-null   float64
#  4   CO2_room                          2764 non-null   float64
#  5   Relative_humidity_(dinning-room)  2764 non-null   float64
#  6   Relative_humidity_room            2764 non-null   float64
#  7   Lighting_(dinning-room)           2764 non-null   float64
#  8   Lighting_room                     2764 non-null   float64
#  9   Meteo_Rain                        2764 non-null   float64
#  10  Meteo_Sun_dusk                    2764 non-null   float64
#  11  Meteo_Wind                        2764 non-null   float64
#  12  Meteo_Sun_light_in_west_facade    2764 non-null   float64
#  13  Meteo_Sun_light_in_east_facade    2764 non-null   float64
#  14  Meteo_Sun_light_in_south_facade   2764 non-null   float64
#  15  Meteo_Sun_irradiance              2764 non-null   float64
#  16  Outdoor_relative_humidity_Sensor  2764 non-null   float64
#  17  Day_of_the_week                   2764 non-null   float64
#  18  Indoor_temperature_room           2764 non-null   float64
# dtypes: float64(16), int64(1), object(2)
# memory usage: 410.4+ KB

# %% [markdown]
# from above we can see data and time is only object data type and that data we are not including in our training so we don't need to handle categorical data.
# Other data types are float.

# %%
#Seperate depedent and independent variables
x=df.iloc[:,3:17] #INDEPENDENT VARIABLE
y=df.iloc[:,18:] #DEPENDENT VARIABLE

# %%
x.head()
# Out:
#    CO2_(dinning-room)  CO2_room  Relative_humidity_(dinning-room)  \
# 0             216.560   221.920                           39.9125
# 1             219.947   220.363                           39.9267
# 2             219.403   218.933                           39.7720
# 3             218.613   217.045                           39.7760
# 4             217.714   216.080                           39.7757
#
#    Relative_humidity_room  Lighting_(dinning-room)  Lighting_room  Meteo_Rain  \
# 0                 42.4150                  81.6650        113.520         0.0
# 1                 42.2453                  81.7413        113.605         0.0
# 2                 42.2267                  81.4240        113.600         0.0
# 3                 42.0987                  81.5013        113.344         0.0
# 4                 42.0686                  81.4657        113.034         0.0
#
#    Meteo_Sun_dusk  Meteo_Wind  Meteo_Sun_light_in_west_facade  \
# 0         623.360     1.42625                         9690.24
# 1         623.211     1.59200                        11022.00
# 2         622.656     1.89133                        13960.50
# 3         622.571     1.82800                        18511.20
# 4         622.400     2.36071                        26349.00
#
#    Meteo_Sun_light_in_east_facade  Meteo_Sun_light_in_south_facade  \
# 0                        12604.20                          95436.8
# 1                        10787.20                          95436.8
# 2                         9669.63                          95398.6
# 3                         9648.13                          95360.3
# 4                         9208.32                          95354.9
#
#    Meteo_Sun_irradiance  Outdoor_relative_humidity_Sensor
# 0               758.880                           48.3750
# 1               762.069                           47.8080
# 2               766.251                           47.4320
# 3               766.037                           47.0240
# 4               762.743                           45.4743

# %%
y.head()
# Out:
#    Indoor_temperature_room
# 0                  17.8275
# 1                  18.1207
# 2                  18.4367
# 3                  18.7513
# 4                  19.0414

# %%
#splitting data into train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=1)

# %%
#Data Scalling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train_scaled = sc.fit_transform(x_train)
x_test_scaled = sc.transform(x_test)

# %% [markdown]
# ## Model Building

# %% [markdown]
# 4 classification algorithms are used in model building
#
#     Linear Regression Model
#     Random Forest model
#     Light Gradient Boost Model
#     Xgboost model

# %% [markdown]
# ### Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
lir = LinearRegression()
lir.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
pred=lir.predict(x_test_scaled)

# %%
from sklearn.metrics import r2_score 
r2_score(pred,y_test)
# Out:
# 0.17425288988529142

# %% [markdown]
# ### Random Forest model

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# C:\Users\ajayp\AppData\Local\Temp\ipykernel_23920\1149647727.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# RandomForestRegressor()

# %%
pred1 = rf.predict(x_test)

# %%
pred1
# Out:
# array([21.618334, 21.27269 , 18.909898, 15.396623, 15.288172, 18.462552,
#        18.204108, 16.202799, 18.322967, 18.155539, 22.021283, 16.58721 ,
#        22.697447, 21.566378, 17.959353, 19.616625, 20.294848, 17.980272,
#        21.621567, 16.256448, 19.670394, 16.147082, 16.783248, 20.391394,
#        18.980112, 18.977458, 23.096354, 22.551678, 12.337911, 22.208924,
#        17.938796, 20.168189, 20.216059, 21.008815, 18.018247, 15.705856,
#        17.758723, 16.323511, 15.072934, 21.735057, 20.847159, 21.016636,
#        22.55878 , 15.80513 , 16.095872, 16.313321, 17.598209, 19.787262,
#        20.251053, 22.764732, 18.696833, 21.68169 , 19.4337  , 18.772987,
#        22.171107, 22.857391, 17.831792, 17.5866  , 22.158708, 16.503597,
#        22.838108, 19.484439, 19.497019, 19.784071, 22.503241, 17.07812 ,
#        18.745744, 20.694292, 20.093232, 21.255181, 19.529829, 17.89106 ,
#        17.402334, 22.201753, 22.010371, 16.270639, 20.117584, 22.671754,
#        19.602795, 16.679414, 24.322784, 18.335331, 19.024312, 20.241291,
#        18.410515, 19.442757, 17.542119, 22.302715, 19.638932, 17.476433,
#        20.807519, 20.576808, 17.788778, 18.677864, 23.66118 , 16.202548,
#        22.286528, 16.016571, 18.383636, 18.607819, 20.013217, 18.394084,
#        19.919494, 19.502399, 17.802137, 18.299756, 16.971486, 17.110558,
#        21.593663, 17.645954, 18.771928, 20.736208, 20.573099, 16.283229,
#        20.86947 , 20.196267, 20.860991, 18.911775, 16.980068, 15.493483,
#        21.891166, 16.950351, 24.250253, 14.725703, 18.815572, 19.706666,
#        17.187997, 22.050765, 19.148183, 18.606242, 15.414811, 13.757267,
#        17.313654, 18.133605, 20.099415, 15.685588, 17.101162, 15.367325,
#        19.86846 , 19.717659, 20.144557, 17.071124, 20.431007, 20.276517,
#        22.817139, 11.900059, 19.848336, 14.934209, 14.429624, 19.803001,
#        19.54613 , 17.185182, 17.440266, 21.166388, 22.911048, 15.800656,
#        19.356168, 20.890221, 20.607741, 19.889627, 23.0076  , 18.072609,
#        20.21195 , 21.937754, 19.949911, 18.640694, 15.556928, 20.598271,
#        18.101349, 19.992784, 16.745189, 20.300804, 18.950211, 20.04361 ,
#        19.270184, 19.034057, 19.110069, 19.620244, 22.066836, 17.925869,
#        12.462741, 22.073402, 16.059034, 17.361704, 18.853867, 16.984906,
#        16.680579, 22.893322, 16.761998, 18.884545, 16.358229, 19.953052,
#        20.834568, 17.845666, 18.170159, 20.063889, 12.205002, 20.24136 ,
#        19.355867, 18.970593, 20.101535, 18.902202, 21.847092, 19.105029,
#        15.093004, 17.3821  , 17.407335, 15.046759, 18.469615, 19.602814,
#        20.778888, 12.870183, 20.329589, 14.226956, 17.60818 , 21.16199 ,
#        20.709225, 20.422288, 21.491508, 18.946729, 16.479882, 21.564167,
#        19.076756, 11.913176, 17.491851, 19.844995, 20.853807, 15.570518,
#        17.760307, 20.961167, 17.119097, 22.076318, 18.873178, 22.264788,
#        11.708009, 22.010273, 21.660913, 22.09898 , 21.81684 , 14.319537,
#        20.040075, 22.468134, 18.787731, 18.854861, 19.017594, 20.598417,
#        19.240752, 19.425371, 14.642636, 19.174101, 17.763442, 20.507018,
#        15.36004 , 18.550498, 20.079203, 15.492871, 18.362875, 24.138267,
#        18.445299, 19.221562, 15.570888, 18.997432, 22.851664, 22.895316,
#        19.781442, 18.72608 , 18.223289, 20.697155, 19.716095, 16.051857,
#        18.347384, 18.16582 , 21.186168, 17.777519, 20.864713, 22.081142,
#        19.34421 , 18.184909, 21.460114, 18.511238, 21.253876, 19.195768,
#        17.774756, 20.88959 , 17.330282, 20.687155, 18.825561, 19.501195,
#        19.468401, 12.765043, 19.109404, 19.771916, 20.560698, 21.882343,
#        14.778589, 20.062473, 18.357634, 16.171713, 18.791829, 14.875551,
#        18.53916 , 15.82628 , 20.485284, 18.060261, 20.529828, 19.00629 ,
#        20.872763, 23.021676, 15.948488, 15.121172, 19.092715, 15.875418,
#        18.504157, 20.105367, 18.432358, 21.317551, 16.325703, 19.596009,
#        16.658242, 20.261232, 20.365819, 23.787365, 21.993934, 22.042596,
#        16.417855, 14.955972, 18.895326, 15.705613, 16.273943, 17.958925,
#        17.543381, 11.909012, 12.737562, 16.63398 , 18.264755, 21.795551,
#        21.80192 , 20.777839, 20.403866, 16.753346, 18.890734, 20.462633,
#        19.04645 , 21.753515, 20.986199, 20.013459, 19.165719, 18.913203,
#        14.711298, 16.339501, 18.822888, 21.382754, 20.367631, 20.030009,
#        19.033677, 22.516291, 20.197896, 18.552051, 20.146027, 20.66564 ,
#        11.905169, 17.03631 , 11.850831, 19.596925, 17.608987, 22.513089,
#        19.45657 , 24.17227 , 19.57737 , 16.619204, 13.796661, 21.958952,
#        11.261196, 18.955842, 19.778436, 19.451931, 11.886717, 18.614954,
#        17.524472, 16.348278, 20.53925 , 17.592723, 20.376639, 16.242743,
#        19.678096, 18.875348, 15.495344, 17.770164, 14.517718, 18.638053,
#        14.641842, 19.112529, 21.725518, 14.601314, 19.934795, 21.657649,
#        17.712436, 18.515208, 19.464249, 16.75252 , 23.170471, 22.972867,
#        15.783801, 23.303336, 15.027146, 18.845572, 16.107525, 18.230661,
#        15.060641, 19.356532, 17.310459, 17.060732, 16.187511, 18.306345,
#        19.927862, 18.708364, 23.153613, 20.59642 , 17.581307, 20.79073 ,
#        20.120005, 18.827492, 19.598315, 16.255922, 14.668952, 16.914852,
#        16.205806, 21.636553, 19.198329, 12.263135, 18.169311, 19.414904,
#        17.018544, 20.31017 , 21.859346, 20.462961, 20.603377, 22.467776,
#        22.253387, 18.07815 , 19.951883, 17.182573, 19.512245, 21.954883,
#        23.318497, 16.064284, 21.518583, 14.82582 , 20.624217, 13.943263,
#        17.346774, 17.964836, 20.044859, 18.160314, 16.644036, 16.237193,
#        20.527624, 14.94691 , 22.731657, 22.517013, 17.593089, 19.864507,
#        21.847237, 18.633389, 20.762956, 19.672872, 20.612297, 14.96549 ,
#        22.093517, 19.060632, 20.562116, 20.489087, 19.537834, 19.926831,
#        19.931026, 16.203697, 20.188882, 21.313318, 17.799825, 17.066697,
#        23.445695, 17.245292, 17.934063, 19.126026, 18.140964, 19.7984  ,
#        23.443904, 19.95565 , 16.763636, 19.151214, 19.010609, 22.96811 ,
#        19.947993, 14.407738, 24.319479, 16.721504, 17.467379, 20.010323,
#        22.409455, 24.711071, 16.838958, 18.224095, 11.694689, 16.439575,
#        19.09967 , 17.502085, 19.46948 , 18.949645, 18.248133, 18.833105,
#        17.168229, 19.365298, 13.538818, 19.884363, 22.374288, 20.120746,
#        22.098691, 20.797334, 18.605933, 20.504983, 19.937793, 21.222578,
#        17.800692, 20.227183, 20.851559, 20.280345, 21.055053, 19.829838,
#        20.280853, 18.008058, 13.717738, 15.392291, 23.662512, 14.751083,
#        21.125975, 15.291509, 19.154277, 18.515462, 20.424586, 16.917322,
#        22.765383, 20.883757, 17.731073, 18.293642, 22.988507, 14.989246,
#        19.187778, 23.64893 , 13.79594 , 19.588238, 14.620315, 15.926224,
#        20.601133, 18.831214, 19.400399, 17.567208, 17.895076, 20.892451,
#        18.504615, 18.983435, 15.050635, 17.510772, 15.680845, 17.621425,
#        22.706666, 19.61642 , 18.162742, 20.178262, 17.362545, 19.588402,
#        20.907503, 16.280881, 18.856383, 22.488097, 20.42516 , 18.97563 ,
#        20.497316, 11.692443, 17.805143, 15.828862, 19.521357, 18.542687,
#        18.855388, 22.133733, 19.566478, 22.34112 , 19.155551, 17.339177,
#        18.680789, 19.950977, 19.35393 , 18.179964, 18.671006, 17.356274,
#        18.057718, 12.879317, 17.376125, 20.612496, 16.69907 , 22.236668,
#        18.4776  , 18.29004 , 19.348034, 17.654655, 22.034826, 18.362869,
#        18.914733, 19.324117, 16.416001, 14.892781, 21.540204, 17.837894,
#        18.834908, 19.846409, 14.522225, 20.083507, 20.216478, 18.724356,
#        19.633208, 22.808621, 17.314929, 11.883249, 21.881228, 13.490066,
#        15.160746, 18.614344, 20.817678, 17.898806, 12.411446, 18.15959 ,
#        20.481364, 21.377183, 19.930784, 22.072918, 15.011097, 21.218312,
#        23.20001 , 15.202004, 11.702677, 21.590349, 20.740068, 17.575531,
#        18.802581, 13.37361 , 22.842736, 16.478556, 20.851828, 15.793293,
#        19.410991, 17.649735, 17.09609 , 18.068046, 13.552006, 17.905822,
#        14.651547, 16.996052, 17.976774, 15.909953, 15.677514, 20.352982,
#        20.236324, 20.578408, 17.022287, 18.504071, 14.501534, 19.785308,
#        20.960959, 20.363768, 20.598196, 20.675981, 20.689636, 24.017889,
#        18.092762, 13.976857, 19.923837, 17.69723 , 18.826772, 20.257387,
#        16.864794, 20.798843, 19.414927, 17.448917, 15.876527, 19.993779,
#        19.570921, 19.002547, 18.009258, 18.837834, 18.452567, 18.099412,
#        23.124175, 17.296914, 18.569124, 15.053096, 18.153478, 11.88457 ,
#        14.995128, 22.300582, 20.139097, 23.023294, 21.227739, 22.77142 ,
#        18.235046, 22.786385, 12.743237, 21.102047, 18.446344, 17.591286,
#        18.452981, 18.510257, 18.669558, 21.171216, 18.261886, 18.528073,
#        15.230886, 21.988199, 18.061497, 20.779146, 16.19721 , 22.4398  ,
#        12.600984, 18.778984, 15.497011, 19.023304, 19.761391, 19.376355,
#        18.821057, 19.206252, 15.66429 , 18.176826, 20.356548, 18.039486,
#        16.002087, 21.445898, 21.923466, 19.966422, 22.504356, 21.60667 ,
#        18.141319, 20.5618  , 19.66444 , 22.494169, 15.640817, 20.553643,
#        15.779058, 17.53868 , 20.430951, 17.847468, 17.540823, 20.871069,
#        19.623425, 17.070118, 18.920675, 16.58526 , 14.058304, 20.065102,
#        20.662297, 19.825179, 20.850373, 20.777974, 20.429478, 21.017417,
#        19.849268, 22.158416, 21.362426, 24.515122, 22.390321, 19.245977,
#        16.488128, 15.493202, 17.601134, 15.169953, 21.660533, 20.595411,
#        20.263292, 16.188133, 18.178317, 19.947681, 20.548081, 22.321657,
#        22.712608, 20.89026 , 17.888614, 18.670478, 17.607494, 19.84843 ,
#        18.91686 , 16.532043, 19.432296, 18.935934, 17.190095, 22.421386,
#        14.745527, 19.787242, 22.349803, 14.712631, 18.311602, 22.682823,
#        20.136947, 17.573964, 20.078122, 17.401325, 19.961085, 15.534827,
#        20.298532, 17.809419, 18.665007, 20.57346 , 12.894584, 20.812522,
#        19.000142, 18.586902, 15.17914 , 22.381449, 13.322492, 21.746039,
#        20.747797, 18.38582 , 16.501958, 16.497876, 20.06732 , 16.938607,
#        17.80669 , 18.014702, 20.920922, 16.36431 , 19.132246, 18.132025,
#        18.579526, 19.591225])

# %%
r2_score(y_test, pred1)
# Out:
# 0.9194343408777197

# %% [markdown]
# ### Light Gradient Boost Model

# %%
lg = lgb.LGBMRegressor()

# %%
lg.fit(x_train,y_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000268 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3303
# [LightGBM] [Info] Number of data points in the train set: 1934, number of used features: 14
# [LightGBM] [Info] Start training from score 18.826209
# LGBMRegressor()

# %%
pred2 = lg.predict(x_test)

# %%
r2_score(y_test, pred2)
# Out:
# 0.9360756052934541

# %% [markdown]
# ### Xgboost Model

# %%
xg = xgb.XGBRegressor()

# %%
xg.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
pred3 = xg.predict(x_test)

# %%
r2_score(y_test,pred3)
# Out:
# 0.9312711740450739

# %%
xg1 = xgb.XGBRegressor()
xg1.fit(x_train_scaled,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
#     *Model*       *r2_score*
#      lir           17.4%
#      rf            91.7%
#      lg            93.6%
#      xg            93.1%
#
# Here above lg is the best model, hence we will export the model

# %%
import pickle
pickle.dump(lg,open('temperature.pkl','wb'))

# %% [markdown]
# ## More Evaluations

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
#for Light Gredient Model
mse = mean_squared_error(y_test, pred2)
mse
# Out:
# 0.5007536664270105

# %%
y_test_np = y_test.values
y_test_np
# Out:
# array([[21.6   ],
#        [21.5773],
#        [18.3153],
#        [15.4027],
#        [15.0787],
#        [17.5153],
#        [17.8813],
#        [15.488 ],
#        [18.1313],
#        [18.068 ],
#        [22.3067],
#        [16.7953],
#        [23.588 ],
#        [21.7973],
#        [16.9173],
#        [19.6067],
#        [19.7733],
#        [17.856 ],
#        [21.188 ],
#        [15.684 ],
#        [18.836 ],
#        [16.2967],
#        [17.0253],
#        [20.8147],
#        [19.    ],
#        [19.0353],
#        [23.9307],
#        [22.6173],
#        [12.638 ],
#        [22.776 ],
#        [18.1033],
#        [20.028 ],
#        [19.9513],
#        [20.328 ],
#        [17.8213],
#        [14.4347],
#        [16.7867],
#        [16.2267],
#        [14.992 ],
#        [21.668 ],
#        [20.584 ],
#        [21.06  ],
#        [23.1307],
#        [15.6087],
#        [16.63  ],
#        [16.7087],
#        [16.852 ],
#        [19.5367],
#        [20.4927],
#        [22.9787],
#        [18.25  ],
#        [22.344 ],
#        [18.166 ],
#        [19.338 ],
#        [22.1493],
#        [23.048 ],
#        [17.308 ],
#        [17.5733],
#        [22.808 ],
#        [20.2733],
#        [22.7307],
#        [19.4727],
#        [19.1607],
#        [19.664 ],
#        [22.3973],
#        [16.3827],
#        [19.304 ],
#        [21.008 ],
#        [20.9707],
#        [21.132 ],
#        [18.536 ],
#        [17.848 ],
#        [17.1547],
#        [22.316 ],
#        [22.464 ],
#        [15.2293],
#        [19.894 ],
#        [23.056 ],
#        [20.0473],
#        [17.42  ],
#        [24.5093],
#        [18.5567],
#        [18.6673],
#        [19.2533],
#        [18.4967],
#        [19.0414],
#        [16.9153],
#        [22.24  ],
#        [19.6913],
#        [18.0047],
#        [21.1547],
#        [20.9813],
#        [17.78  ],
#        [18.7533],
#        [23.456 ],
#        [15.5033],
#        [22.608 ],
#        [14.7227],
#        [18.34  ],
#        [19.34  ],
#        [20.    ],
#        [20.7893],
#        [19.7933],
#        [19.494 ],
#        [17.2353],
#        [18.2967],
#        [16.4067],
#        [18.232 ],
#        [21.62  ],
#        [18.348 ],
#        [18.4167],
#        [20.2973],
#        [21.184 ],
#        [16.1627],
#        [21.84  ],
#        [20.4167],
#        [20.7027],
#        [18.76  ],
#        [16.7367],
#        [15.32  ],
#        [21.896 ],
#        [16.4647],
#        [24.4453],
#        [12.0113],
#        [18.632 ],
#        [19.3833],
#        [16.8993],
#        [22.    ],
#        [18.444 ],
#        [18.734 ],
#        [14.5613],
#        [13.3473],
#        [16.558 ],
#        [17.9127],
#        [17.98  ],
#        [15.596 ],
#        [17.0767],
#        [15.0773],
#        [20.0633],
#        [20.4447],
#        [19.874 ],
#        [15.814 ],
#        [21.064 ],
#        [17.1773],
#        [22.8733],
#        [11.8867],
#        [20.1147],
#        [12.6727],
#        [12.4453],
#        [20.0947],
#        [20.3247],
#        [16.722 ],
#        [17.7447],
#        [21.244 ],
#        [23.364 ],
#        [16.11  ],
#        [19.364 ],
#        [20.6653],
#        [20.744 ],
#        [19.7767],
#        [23.236 ],
#        [18.8727],
#        [21.072 ],
#        [22.132 ],
#        [20.8267],
#        [18.532 ],
#        [15.4987],
#        [20.632 ],
#        [18.004 ],
#        [19.1527],
#        [16.6447],
#        [21.3707],
#        [18.8673],
#        [20.5827],
#        [18.8913],
#        [19.5493],
#        [18.904 ],
#        [19.8133],
#        [22.244 ],
#        [17.7187],
#        [11.862 ],
#        [22.78  ],
#        [16.032 ],
#        [20.9947],
#        [18.482 ],
#        [16.9367],
#        [16.2273],
#        [23.244 ],
#        [16.52  ],
#        [18.7267],
#        [16.686 ],
#        [19.6747],
#        [21.34  ],
#        [16.054 ],
#        [18.2907],
#        [21.216 ],
#        [11.42  ],
#        [20.1287],
#        [19.4333],
#        [18.8987],
#        [21.7827],
#        [19.2473],
#        [22.0813],
#        [19.846 ],
#        [15.196 ],
#        [19.542 ],
#        [17.05  ],
#        [15.004 ],
#        [18.306 ],
#        [19.56  ],
#        [22.0013],
#        [13.0473],
#        [20.9507],
#        [14.1267],
#        [17.7367],
#        [21.6587],
#        [20.768 ],
#        [20.1507],
#        [22.644 ],
#        [18.914 ],
#        [15.5813],
#        [21.3227],
#        [19.608 ],
#        [11.8493],
#        [16.9467],
#        [19.9913],
#        [19.444 ],
#        [15.0713],
#        [16.6627],
#        [20.9947],
#        [16.17  ],
#        [24.88  ],
#        [18.648 ],
#        [22.2667],
#        [11.7267],
#        [20.952 ],
#        [22.8013],
#        [22.464 ],
#        [22.4067],
#        [13.96  ],
#        [19.59  ],
#        [22.728 ],
#        [18.472 ],
#        [18.494 ],
#        [19.2227],
#        [20.7307],
#        [19.3553],
#        [20.7093],
#        [13.8867],
#        [19.156 ],
#        [17.188 ],
#        [20.4247],
#        [16.1647],
#        [19.3733],
#        [19.9   ],
#        [14.8233],
#        [18.2767],
#        [24.7373],
#        [18.8253],
#        [19.2947],
#        [15.5233],
#        [19.13  ],
#        [23.572 ],
#        [23.32  ],
#        [19.4567],
#        [18.4793],
#        [17.284 ],
#        [20.9813],
#        [19.3053],
#        [16.2133],
#        [18.52  ],
#        [19.2427],
#        [21.688 ],
#        [16.9887],
#        [21.056 ],
#        [22.4707],
#        [19.6433],
#        [16.7887],
#        [22.816 ],
#        [18.2707],
#        [21.1333],
#        [20.3747],
#        [17.24  ],
#        [17.0753],
#        [17.4233],
#        [21.2467],
#        [18.8587],
#        [19.7267],
#        [18.4153],
#        [12.61  ],
#        [18.2447],
#        [19.8453],
#        [20.66  ],
#        [21.8227],
#        [14.912 ],
#        [19.9787],
#        [19.374 ],
#        [15.616 ],
#        [18.338 ],
#        [14.3753],
#        [18.0813],
#        [15.7387],
#        [22.092 ],
#        [17.9333],
#        [20.844 ],
#        [19.464 ],
#        [22.164 ],
#        [23.408 ],
#        [15.416 ],
#        [13.046 ],
#        [17.8007],
#        [16.2973],
#        [18.8007],
#        [20.3407],
#        [19.06  ],
#        [21.528 ],
#        [16.4027],
#        [19.5193],
#        [15.824 ],
#        [20.1073],
#        [22.036 ],
#        [24.3493],
#        [21.2053],
#        [22.064 ],
#        [16.4687],
#        [14.868 ],
#        [19.9987],
#        [15.002 ],
#        [16.7853],
#        [19.3387],
#        [17.6047],
#        [11.9267],
#        [12.5667],
#        [17.7433],
#        [18.082 ],
#        [21.928 ],
#        [21.4267],
#        [20.9307],
#        [20.5987],
#        [16.918 ],
#        [18.7267],
#        [20.624 ],
#        [18.7733],
#        [22.1587],
#        [22.3453],
#        [20.2427],
#        [19.508 ],
#        [19.28  ],
#        [14.0793],
#        [16.2   ],
#        [19.328 ],
#        [22.5533],
#        [20.476 ],
#        [19.144 ],
#        [19.22  ],
#        [22.6987],
#        [21.0733],
#        [17.306 ],
#        [20.5853],
#        [19.314 ],
#        [11.8553],
#        [15.9987],
#        [11.826 ],
#        [19.7833],
#        [17.8427],
#        [22.832 ],
#        [19.42  ],
#        [24.6293],
#        [19.45  ],
#        [18.4767],
#        [13.678 ],
#        [21.948 ],
#        [11.0787],
#        [17.508 ],
#        [19.65  ],
#        [20.7053],
#        [11.89  ],
#        [17.3367],
#        [17.142 ],
#        [15.596 ],
#        [20.7747],
#        [17.6487],
#        [18.208 ],
#        [16.16  ],
#        [17.9047],
#        [19.274 ],
#        [13.876 ],
#        [17.28  ],
#        [14.5707],
#        [18.8067],
#        [13.5507],
#        [19.81  ],
#        [21.716 ],
#        [14.638 ],
#        [19.8   ],
#        [21.3867],
#        [18.424 ],
#        [18.9833],
#        [19.328 ],
#        [16.9953],
#        [23.5653],
#        [23.4   ],
#        [15.8567],
#        [23.4333],
#        [14.38  ],
#        [19.1133],
#        [13.9167],
#        [18.6867],
#        [15.    ],
#        [18.7487],
#        [18.0533],
#        [16.6473],
#        [15.724 ],
#        [18.46  ],
#        [19.4693],
#        [18.6193],
#        [22.796 ],
#        [20.564 ],
#        [17.196 ],
#        [20.362 ],
#        [19.882 ],
#        [19.    ],
#        [19.6033],
#        [16.1993],
#        [15.376 ],
#        [16.4167],
#        [18.816 ],
#        [21.7493],
#        [19.3853],
#        [12.332 ],
#        [20.064 ],
#        [19.144 ],
#        [16.8133],
#        [21.744 ],
#        [22.2333],
#        [21.004 ],
#        [20.636 ],
#        [22.544 ],
#        [22.0427],
#        [18.4233],
#        [20.1787],
#        [16.6573],
#        [18.338 ],
#        [22.1787],
#        [23.0587],
#        [15.1887],
#        [19.712 ],
#        [14.8407],
#        [20.892 ],
#        [12.1713],
#        [16.9367],
#        [18.0973],
#        [19.74  ],
#        [17.3347],
#        [15.78  ],
#        [15.74  ],
#        [21.0173],
#        [14.8947],
#        [22.8093],
#        [24.896 ],
#        [17.516 ],
#        [19.9527],
#        [21.744 ],
#        [17.0067],
#        [20.4507],
#        [19.4   ],
#        [20.8187],
#        [15.136 ],
#        [22.0813],
#        [18.4167],
#        [20.136 ],
#        [20.8373],
#        [19.3653],
#        [19.504 ],
#        [21.1187],
#        [14.96  ],
#        [19.8393],
#        [21.44  ],
#        [18.6787],
#        [17.244 ],
#        [23.588 ],
#        [17.766 ],
#        [17.9347],
#        [19.3327],
#        [17.586 ],
#        [19.2967],
#        [23.74  ],
#        [20.616 ],
#        [14.4067],
#        [18.2447],
#        [19.12  ],
#        [23.484 ],
#        [22.0253],
#        [14.8427],
#        [24.8013],
#        [16.352 ],
#        [19.4873],
#        [19.93  ],
#        [23.2667],
#        [24.912 ],
#        [16.2247],
#        [19.0287],
#        [11.65  ],
#        [16.448 ],
#        [19.1547],
#        [17.6973],
#        [19.0647],
#        [18.7753],
#        [17.1167],
#        [19.2327],
#        [16.7687],
#        [19.348 ],
#        [13.61  ],
#        [20.2293],
#        [23.2   ],
#        [21.932 ],
#        [22.2973],
#        [20.616 ],
#        [18.138 ],
#        [21.156 ],
#        [20.3087],
#        [21.748 ],
#        [17.6113],
#        [20.1627],
#        [21.92  ],
#        [19.524 ],
#        [20.664 ],
#        [19.2667],
#        [20.454 ],
#        [20.0847],
#        [13.614 ],
#        [16.016 ],
#        [23.2613],
#        [15.6053],
#        [19.3193],
#        [14.798 ],
#        [19.49  ],
#        [16.97  ],
#        [20.4433],
#        [17.0813],
#        [22.672 ],
#        [21.716 ],
#        [17.3633],
#        [17.818 ],
#        [23.4733],
#        [14.9433],
#        [19.724 ],
#        [23.88  ],
#        [13.654 ],
#        [19.762 ],
#        [15.1567],
#        [15.4067],
#        [21.4693],
#        [18.9967],
#        [19.2513],
#        [17.3753],
#        [16.4513],
#        [21.024 ],
#        [19.1493],
#        [20.29  ],
#        [16.0867],
#        [16.724 ],
#        [13.986 ],
#        [17.6   ],
#        [24.7947],
#        [18.8993],
#        [19.7833],
#        [20.0133],
#        [17.2167],
#        [20.184 ],
#        [20.9293],
#        [14.586 ],
#        [18.702 ],
#        [22.4133],
#        [19.6113],
#        [18.676 ],
#        [21.0027],
#        [11.6847],
#        [18.036 ],
#        [15.9273],
#        [19.4   ],
#        [18.8007],
#        [18.752 ],
#        [22.228 ],
#        [19.5573],
#        [21.624 ],
#        [18.944 ],
#        [17.508 ],
#        [19.97  ],
#        [20.908 ],
#        [19.8067],
#        [16.818 ],
#        [19.332 ],
#        [17.1533],
#        [18.448 ],
#        [12.708 ],
#        [21.44  ],
#        [20.668 ],
#        [18.15  ],
#        [22.8653],
#        [18.3593],
#        [17.6987],
#        [18.7627],
#        [17.6673],
#        [21.556 ],
#        [20.44  ],
#        [18.7433],
#        [18.9867],
#        [16.3167],
#        [14.8333],
#        [21.6   ],
#        [18.0993],
#        [18.6567],
#        [20.3447],
#        [14.7247],
#        [19.8067],
#        [21.34  ],
#        [17.0933],
#        [19.45  ],
#        [23.564 ],
#        [17.1067],
#        [11.8767],
#        [21.7267],
#        [13.5367],
#        [15.878 ],
#        [18.4667],
#        [21.1373],
#        [19.2273],
#        [12.1687],
#        [17.8287],
#        [20.2947],
#        [21.4467],
#        [20.8453],
#        [22.352 ],
#        [14.41  ],
#        [22.0693],
#        [23.64  ],
#        [13.9633],
#        [11.6233],
#        [21.3947],
#        [20.8453],
#        [17.5733],
#        [18.2347],
#        [13.272 ],
#        [23.8213],
#        [16.016 ],
#        [21.    ],
#        [16.3287],
#        [17.1067],
#        [14.78  ],
#        [16.6233],
#        [18.0713],
#        [13.57  ],
#        [18.1887],
#        [12.1273],
#        [17.3527],
#        [18.032 ],
#        [15.1033],
#        [15.0867],
#        [21.048 ],
#        [20.508 ],
#        [20.896 ],
#        [17.3593],
#        [17.508 ],
#        [14.498 ],
#        [19.65  ],
#        [21.788 ],
#        [20.8787],
#        [20.788 ],
#        [20.7093],
#        [20.572 ],
#        [24.2653],
#        [18.4087],
#        [13.6167],
#        [19.024 ],
#        [17.9967],
#        [17.8107],
#        [20.6093],
#        [17.4333],
#        [20.764 ],
#        [19.7567],
#        [16.53  ],
#        [14.5573],
#        [19.4753],
#        [18.8973],
#        [19.018 ],
#        [17.548 ],
#        [17.9613],
#        [19.7147],
#        [18.036 ],
#        [22.7573],
#        [17.6153],
#        [19.2633],
#        [14.8933],
#        [18.4167],
#        [11.9033],
#        [14.6727],
#        [22.2907],
#        [20.5707],
#        [24.0213],
#        [18.1433],
#        [23.0293],
#        [18.216 ],
#        [22.908 ],
#        [12.3867],
#        [21.1373],
#        [18.524 ],
#        [17.038 ],
#        [18.8727],
#        [20.52  ],
#        [20.504 ],
#        [21.94  ],
#        [17.2347],
#        [18.1853],
#        [13.37  ],
#        [22.232 ],
#        [18.3333],
#        [21.316 ],
#        [15.684 ],
#        [22.9587],
#        [12.2107],
#        [20.0253],
#        [15.6507],
#        [19.3813],
#        [20.0947],
#        [18.9547],
#        [18.486 ],
#        [19.44  ],
#        [14.8393],
#        [18.4647],
#        [20.6973],
#        [17.5007],
#        [15.872 ],
#        [21.996 ],
#        [22.1267],
#        [19.9493],
#        [23.408 ],
#        [22.0213],
#        [17.556 ],
#        [20.8107],
#        [20.5387],
#        [23.032 ],
#        [15.7127],
#        [20.4173],
#        [14.7467],
#        [17.4933],
#        [19.2467],
#        [20.174 ],
#        [18.6067],
#        [21.808 ],
#        [19.4067],
#        [15.706 ],
#        [18.8607],
#        [16.1033],
#        [13.7947],
#        [19.902 ],
#        [20.608 ],
#        [19.74  ],
#        [20.7107],
#        [21.784 ],
#        [21.196 ],
#        [21.2853],
#        [20.25  ],
#        [21.74  ],
#        [18.2793],
#        [24.6507],
#        [22.5427],
#        [18.714 ],
#        [15.8047],
#        [15.1607],
#        [19.4933],
#        [14.9533],
#        [21.3813],
#        [20.78  ],
#        [20.644 ],
#        [16.426 ],
#        [18.316 ],
#        [19.8933],
#        [20.84  ],
#        [22.404 ],
#        [23.164 ],
#        [20.9507],
#        [20.1053],
#        [19.2767],
#        [12.446 ],
#        [19.536 ],
#        [17.3013],
#        [16.056 ],
#        [19.1407],
#        [19.0827],
#        [17.056 ],
#        [22.756 ],
#        [14.2733],
#        [19.84  ],
#        [22.404 ],
#        [14.7367],
#        [18.1073],
#        [22.8747],
#        [19.5187],
#        [17.4167],
#        [20.1227],
#        [16.248 ],
#        [20.2833],
#        [15.324 ],
#        [21.0253],
#        [17.7667],
#        [19.2633],
#        [19.2833],
#        [12.8527],
#        [21.024 ],
#        [18.632 ],
#        [18.614 ],
#        [15.2873],
#        [22.42  ],
#        [13.302 ],
#        [21.8347],
#        [20.624 ],
#        [17.1727],
#        [16.3633],
#        [16.0273],
#        [20.326 ],
#        [16.61  ],
#        [16.8367],
#        [17.4667],
#        [20.652 ],
#        [15.6427],
#        [18.9613],
#        [18.1567],
#        [18.0667],
#        [20.684 ]])

# %%
#Scatter plot of actual vs predicted values
plt.scatter(y_test, pred2)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()

# Residuals (difference between actual and predicted values)
residuals = y_test_np - pred2

# Histogram of residuals
plt.hist(residuals, bins=50)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.show()

# %%
#for Light Gredient Model
mae = mean_absolute_error(y_test, pred2)
mae
# Out:
# 0.5089989459469727

# %%
# Histogram of residuals
plt.hist(np.abs(residuals), bins=50)  # Use np.abs to get absolute values for MAE
plt.xlabel('Absolute Residuals')
plt.ylabel('Frequency')
plt.title('Histogram of Absolute Residuals')
plt.show()

# %%
#for Light Gredient Model
rmse = np.sqrt(mse)
rmse
# Out:
# 0.7076395031560989

# %%
# Histogram of absolute residuals (for RMSE)
plt.hist(np.abs(residuals), bins=50)
plt.xlabel('Absolute Residuals')
plt.ylabel('Frequency')
plt.title('Histogram of Absolute Residuals (RMSE)')
plt.show()

# %%
# Histogram of absolute residuals (for RMSE)
plt.hist(residuals, bins=50)
plt.xlabel('Absolute Residuals')
plt.ylabel('Frequency')
plt.title('Histogram of Absolute Residuals (RMSE)')
plt.show()

# %%
#for Linear Regression Model
mae = mean_absolute_error(y_test, pred)
print(mae)
mse1 = mean_squared_error(y_test, pred)
print(mse)
nrmse = np.sqrt(mse1)
print(nrmse)
r2_score(y_test,pred)
# Out:
# 1.572677907866914
# 3.7427887580824297
# 1.934628842461114
# 0.5222091780535016

# %%
#for Random Forest Model
mae = mean_absolute_error(y_test, pred1)
print(mae)
mse1 = mean_squared_error(y_test, pred1)
print(mse1)
nrmse = np.sqrt(mse1)
print(nrmse)
r2_score(y_test,pred1)
# Out:
# 0.5211940722891568
# 0.6311135111844771
# 0.7944265297587166
# 0.9194343408777197

# %%
#for Light Gradient Boost Model
mae = mean_absolute_error(y_test, pred2)
print(mae)
mse1 = mean_squared_error(y_test, pred2)
print(mse1)
nrmse = np.sqrt(mse1)
print(nrmse)
r2_score(y_test,pred2)
# Out:
# 0.5089989459469727
# 0.5007536664270105
# 0.7076395031560989
# 0.9360756052934541

# %%
#for XgBoost Model
mae = mean_absolute_error(y_test, pred3)
print(mae)
mse1 = mean_squared_error(y_test, pred3)
print(mse1)
nrmse = np.sqrt(mse1)
print(nrmse)
r2_score(y_test,pred3)
# Out:
# 0.5326548784995941
# 0.5383893229516795
# 0.7337501774798283
# 0.9312711740450739
